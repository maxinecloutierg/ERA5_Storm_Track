# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
vors = df24.loc[df24.HU == True]

print('mean               : ' , "{:.2e}".format(vors['VORS_av08'].mean()))
print('standard deviation : ', "{:.2e}".format(vors['VORS_av08'].std()))
# Out:
# mean               :  2.08e-05
# standard deviation :  1.09e-05

# %%
mean = vors['VORS_av08'].mean()
sigma = vors['VORS_av08'].std()

mean = '{:0.2e}'.format(mean)
sigma = '{:0.2e}'.format(sigma)


mean = mean[0 : 4]
sigma = sigma[0 : 4]

# %%
df = pd.read_csv('/pampa/cloutier/storm_tracks/NAEC/NAEC_1979-2020_max_season.csv')
#df = pd.read_csv('/pampa/cloutier/storm_tracks/filtered/etc24_consec_v3.csv')

# %% [markdown]
# ## BON CODE POUR PLOT, MAIS MAUVAISES DONNÉES

# %%
df24 = pd.read_csv('/pampa/cloutier/storm_tracks/NAEC/NAEC_1979-2020_max_season.csv')

seasons = ['JJA', 'SON', 'DJF', 'MAM']
bins = np.arange(-2, 5, 0.5)
i = 0.1 # shift bars ne
plt.figure(figsize=(13,3))
colors = ['red', 'orange', 'royalblue', 'g']
max_pct = 0

for season, color in zip (seasons, colors) : 
    df = df24.loc[(df24.season == season) & (df24.HU == True)]
    avg_vors = df.groupby('storm')['VORS_av08'].mean()
    std_vors = (avg_vors - avg_vors.mean()) / avg_vors.std()
    frequency, _ = np.histogram(std_vors, bins=bins)
    tot_etc = len(std_vors)
    pct = (frequency / tot_etc) * 100
    
    plt.bar(bins[:-1]+i, pct, width=0.15, alpha=0.7,label=season, color=color)
    
    # establish the max frequency for y axis limit on the bar plot later
    
    if max(pct) > max_pct : 
        max_pct = max(pct)
    i += 0.1
    
plt.xticks(bins[:-1])

# legend customization

legend = plt.legend(frameon=False, ncol=len(seasons), fontsize=16, columnspacing=0.5)
for i, color in zip(range(0,len(seasons)), colors):
    legend.get_texts()[i].set_position((-9, 0.5))
    first_text = legend.get_texts()[i]  # Get the first legend text
    first_text.set_fontweight('bold')  # Set font weight to bold
    first_text.set_color(color)
    first_text.set_alpha(0.8)

plt.xlabel('Standardized NNA-lifetime and 800 km averaged VORS', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(np.arange(0, max_pct, 3))
plt.ylabel('Frequency (%)', fontsize=14)
plt.grid(which='major', axis='x', linestyle='dotted')

textstr = '\n'.join((
    r'$\mathrm{mean}:\ %s \times 10^{-5} \ \mathrm{s^{-1}}$' % mean,
    r'$\qquad \ \sigma:\ %s \times 10^{-5} \ \mathrm{s^{-1}}$' % sigma))

plt.text(2.2, 8, textstr, fontsize=16)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-286-df77b7da1e48> in <module>
#      44
#      45 textstr = '\n'.join((
# ---> 46     r'$\mathrm{mean}:\ %s \times 10^{-5} \ \mathrm{s^{-1}}$' % mean,
#      47     r'$\qquad \ \sigma:\ %s \times 10^{-5} \ \mathrm{s^{-1}}$' % sigma))
#      48
#
# NameError: name 'mean' is not defined

# %%
# Un autre essai...

# %%
# Calculer la moyenne de vors de chaque tempête
df = pd.read_csv('/pampa/cloutier/storm_tracks/NAEC/NAEC_1979-2020_max_season.csv')
df_hu = df.loc[df.HU == True]

mean_std_vors = df.groupby('storm')['VORS_av08'].agg(['mean', 'std'])
mean_std_vors = mean_std_vors.rename(columns={'mean': 'mean_VORS_av08', 'std': 'std_VORS_av08'})

# ajouter les colonnes de moyenne et de std dans le dataframe original
df_hu = df_hu.merge(mean_std_vors, how='left', on='storm')

# Calculer la vors normalisée
df_hu['VORS_av08_norm'] = (df_hu['VORS_av08'] - df_hu['mean_VORS_av08']) / df_hu['std_VORS_av08']

# %%
pivot_table = df_hu.pivot_table(index='VORS_av08_norm', columns='season', 
                             values='storm', aggfunc='count', fill_value=0)

# Define the bin edges for your histogram
bins = [-2.0, -1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4, 4.5]

# Calculate the histogram counts for each season
hist_jja, _ = np.histogram(df_hu[df_hu['season'] == 'JJA']['VORS_av08_norm'], bins=bins)
hist_son, _ = np.histogram(df_hu[df_hu['season'] == 'SON']['VORS_av08_norm'], bins=bins)
hist_djf, _ = np.histogram(df_hu[df_hu['season'] == 'DJF']['VORS_av08_norm'], bins=bins)
hist_mam, _ = np.histogram(df_hu[df_hu['season'] == 'MAM']['VORS_av08_norm'], bins=bins)

# Calculate the frequencies for each season
Bnwdsp_jja = (hist_jja / len(df_hu[df_hu['season'] == 'JJA']['VORS_av08_norm'])) * 100
Bnwdsp_son = (hist_son / len(df_hu[df_hu['season'] == 'SON']['VORS_av08_norm'])) * 100
Bnwdsp_djf = (hist_djf / len(df_hu[df_hu['season'] == 'DJF']['VORS_av08_norm'])) * 100
Bnwdsp_mam = (hist_mam / len(df_hu[df_hu['season'] == 'MAM']['VORS_av08_norm'])) * 100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-319-e77094d5678a> in <module>
# ----> 1 pivot_table = df_hu.pivot_table(index='VORS_av08_norm', columns='season',
#       2                              values='storm', aggfunc='count', fill_value=0)
#       3
#       4 # Define the bin edges for your histogram
#       5 bins = [-2.0, -1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4, 4.5]
#
# /sca/compilers_and_tools/python/miniconda3/envs/base_plus/lib/python3.8/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    7026         from pandas.core.reshape.pivot import pivot_table
#    7027
# -> 7028         return pivot_table(
#    7029             self,
#    7030             values=values,
#
# ...

# %%
bins = np.arange(-2, 5, 0.5)
width = 0.15
cs2 = plt.bar(bins[:-1] + 0.1, Bnwdsp_jja, width, color='crimson', alpha=0.8)
cs2 = plt.bar(bins[:-1]+ 0.2, Bnwdsp_son, width, color='orange', alpha=0.8)
cs2 = plt.bar(bins[:-1]+ 0.3, Bnwdsp_djf, width, color='royalblue', alpha=0.8)
cs2 = plt.bar(bins[:-1]+ 0.4, Bnwdsp_mam, width, color='green', alpha=0.7)
plt.xticks(bins[:-1])
plt.show()
#plt.bar(bins[:-1]+i, pct, width=0.15, alpha=0.7,label=season, color=color)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-320-abc5b88ed0b1> in <module>
#       1 bins = np.arange(-2, 5, 0.5)
#       2 width = 0.15
# ----> 3 cs2 = plt.bar(bins[:-1] + 0.1, Bnwdsp_jja, width, color='crimson', alpha=0.8)
#       4 cs2 = plt.bar(bins[:-1]+ 0.2, Bnwdsp_son, width, color='orange', alpha=0.8)
#       5 cs2 = plt.bar(bins[:-1]+ 0.3, Bnwdsp_djf, width, color='royalblue', alpha=0.8)
#
# /sca/compilers_and_tools/python/miniconda3/envs/base_plus/lib/python3.8/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %% [markdown]
# ### BON CODE
#
# Utiliser la moyenne et sigma (UNE SEULE VALEUR).

# %%
# Ajouter la moyenne, la déviation standard et la vorticité normalisée dans le df

df_hu = df.loc[df.HU == True]
mean_vors = df_hu['VORS_av08'].mean()
vors_std = df['VORS_av08'].std()

# Perform Z-score normalization on the 'VORS_av08' column
df['VORS_av08_norm'] = (df['VORS_av08'] - mean_vors) / vors_std
# df_hu['VORS_av08_mean'] = mean_vors
# df_hu['VORS_av08_std'] = vors_std

# %%
vors_std = df['VORS_av08'].std()
print(vors_std)
# Out:
# 1.1696535898136264e-05

# %%
# Assuming you have a DataFrame named df with the necessary data and 'VORS_av08_norm' column

#df['VORS_av08_norm'] = df['VORS_av08_norm'].round(1)

# Calculate the frequencies using the rounded values
pivot_table = df.pivot_table(index='VORS_av08_norm', columns='season', 
                             values='storm', aggfunc='count', fill_value=0)

# Define the bin edges for your histogram
bins = [-2.0, -1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4, 4.5]

# Calculate the histogram counts for each season
hist_jja, _ = np.histogram(df[df['season'] == 'JJA']['VORS_av08_norm'], bins=bins)
hist_son, _ = np.histogram(df[df['season'] == 'SON']['VORS_av08_norm'], bins=bins)
hist_djf, _ = np.histogram(df[df['season'] == 'DJF']['VORS_av08_norm'], bins=bins)
hist_mam, _ = np.histogram(df[df['season'] == 'MAM']['VORS_av08_norm'], bins=bins)

# Calculate the frequencies for each season
Bnwdsp_jja = (hist_jja / len(df[df['season'] == 'JJA']['VORS_av08_norm'])) * 100
Bnwdsp_son = (hist_son / len(df[df['season'] == 'SON']['VORS_av08_norm'])) * 100
Bnwdsp_djf = (hist_djf / len(df[df['season'] == 'DJF']['VORS_av08_norm'])) * 100
Bnwdsp_mam = (hist_mam / len(df[df['season'] == 'MAM']['VORS_av08_norm'])) * 100

# %%
plt.figure(figsize=(12,4))
bins = np.arange(-2, 5, 0.5)
width = 0.15
cs2 = plt.bar(bins[:-1] + 0.1, Bnwdsp_jja, width, color='crimson', alpha=0.8)
cs2 = plt.bar(bins[:-1]+ 0.2, Bnwdsp_son, width, color='orange', alpha=0.8)
cs2 = plt.bar(bins[:-1]+ 0.3, Bnwdsp_djf, width, color='royalblue', alpha=0.8)
cs2 = plt.bar(bins[:-1]+ 0.4, Bnwdsp_mam, width, color='green', alpha=0.8)
plt.xticks(bins[:-1])
plt.show()

# %%
# CODE CHEN
# Before opening Python execute:
#   module load python3
#   development/python3-rpn-code
#   source activate base_plus
#

import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np                         # Good module for matrix and matrix operation
import matplotlib as mpl
import matplotlib.pyplot as plt            # Module to produce figure
import matplotlib.colors as colors
import os                                  # Used to convert png to other format
from datetime import datetime
from matplotlib import gridspec,rc
from scipy.stats import spearmanr, pearsonr

fs=14
fs1=12
RAD='200km'

data = open('/home/chen/data/storm_analysis/2000-2020_cir_disttr/All_storms_kept_for_2p5Dcir_disttr_allwinds_'+RAD+'.txt','r')

num_jja=[]
num_son=[]
num_djf=[]
num_mam=[]
nvors_jja=[]
nvors_son=[]
nvors_djf=[]
nvors_mam=[]
for i, line in enumerate(data):
    words=line.split()
    if i==5:
        meanvors=float(words[2])
        sigmvors=float(words[3])
    elif i>=6:
        num0=(words[0])
        mm0=(words[1])[4:6]
        nvors0=float(words[11]) #<--nvors
        if mm0 == '09' or mm0 == '10' or mm0 == '11':
            num_son.append(num0)
            nvors_son.append(nvors0)
        elif mm0 == '12' or mm0 == '01' or mm0 == '02':
            num_djf.append(num0)
            nvors_djf.append(nvors0)
        elif mm0 == '03' or mm0 == '04' or mm0 == '05':
            num_mam.append(num0)
            nvors_mam.append(nvors0)
        elif mm0 == '06' or mm0 == '07' or mm0 == '08':
            num_jja.append(num0)
            nvors_jja.append(nvors0)

Q1_jja=0
Q2_jja=0
Q1_son=0
Q2_son=0
Q1_djf=0
Q2_djf=0
Q1_mam=0
Q2_mam=0

for i, txt in enumerate(num_jja):
    if  nvors_jja[i]>=1.:
        Q1_jja+=1
#        #ax.annotate(txt, (npr8[i], nwdsp8[i]),fontsize=8, ha='center', va='center')
    elif  nvors_jja[i]<1.:
        Q2_jja+=1

for i, txt in enumerate(num_son):
    if  nvors_son[i]>=1.:
        Q1_son+=1
    elif  nvors_son[i]<1.:
        Q2_son+=1

for i, txt in enumerate(num_djf):
    if  nvors_djf[i]>=1.:
        Q1_djf+=1
    elif  nvors_djf[i]<1.:
        Q2_djf+=1

for i, txt in enumerate(num_mam):
    if  nvors_mam[i]>=1.:
        Q1_mam+=1
    elif  nvors_mam[i]<1.:
        Q2_mam+=1


#for i, txt in enumerate(num):
#    if  nwdsp8[i]>=1.:
#        Q1+=1
#        #ax.annotate(txt, (npr8[i], nwdsp8[i]),fontsize=8, ha='center', va='center')
#    elif  nwdsp8[i]<1.:
#        Q2+=1

Bnwdsp_jja=np.zeros(13)
Bnwdsp_son=np.zeros(13)
Bnwdsp_djf=np.zeros(13)
Bnwdsp_mam=np.zeros(13)

for i, txt in enumerate(num_jja):
    if  nvors_jja[i]< -2.:
        Bnwdsp_jja[0]+=1
        #ax.annotate(txt, (npr8[i], nwdsp8[i]),fontsize=8, ha='center', va='center')
    elif  nvors_jja[i]>= -2. and nvors_jja[i]< -1.5:
        Bnwdsp_jja[1]+=1
    elif  nvors_jja[i]>= -1.5 and nvors_jja[i]< -1.:
        Bnwdsp_jja[2]+=1
    elif  nvors_jja[i]>= -1. and nvors_jja[i]< -0.5:
        Bnwdsp_jja[3]+=1
    elif  nvors_jja[i]>= -0.5 and nvors_jja[i]< 0.:
        Bnwdsp_jja[4]+=1
    elif  nvors_jja[i]>= 0. and nvors_jja[i]< 0.5:
        Bnwdsp_jja[5]+=1
    elif  nvors_jja[i]>= 0.5 and nvors_jja[i]< 1.:
        Bnwdsp_jja[6]+=1
    elif  nvors_jja[i]>= 1. and nvors_jja[i]< 1.5:
        Bnwdsp_jja[7]+=1
    elif  nvors_jja[i]>= 1.5 and nvors_jja[i]< 2.:
        Bnwdsp_jja[8]+=1
    elif  nvors_jja[i]>= 2. and nvors_jja[i]< 2.5:
        Bnwdsp_jja[9]+=1
    elif  nvors_jja[i]>= 2.5 and nvors_jja[i]< 3.:
        Bnwdsp_jja[10]+=1
    elif  nvors_jja[i]>= 3. and nvors_jja[i]< 3.5:
        Bnwdsp_jja[11]+=1
    elif  nvors_jja[i]>= 3.5:
        Bnwdsp_jja[12]+=1

print('Bnwdsp=',Bnwdsp_jja[:])

for i, txt in enumerate(num_son):
    if  nvors_son[i]< -2.:
        Bnwdsp_son[0]+=1
        #ax.annotate(txt, (npr8[i], nwdsp8[i]),fontsize=8, ha='center', va='center')
    elif  nvors_son[i]>= -2. and nvors_son[i]< -1.5:
        Bnwdsp_son[1]+=1
    elif  nvors_son[i]>= -1.5 and nvors_son[i]< -1.:
        Bnwdsp_son[2]+=1
    elif  nvors_son[i]>= -1. and nvors_son[i]< -0.5:
        Bnwdsp_son[3]+=1
    elif  nvors_son[i]>= -0.5 and nvors_son[i]< 0.:
        Bnwdsp_son[4]+=1
    elif  nvors_son[i]>= 0. and nvors_son[i]< 0.5:
        Bnwdsp_son[5]+=1
    elif  nvors_son[i]>= 0.5 and nvors_son[i]< 1.:
        Bnwdsp_son[6]+=1
    elif  nvors_son[i]>= 1. and nvors_son[i]< 1.5:
        Bnwdsp_son[7]+=1
    elif  nvors_son[i]>= 1.5 and nvors_son[i]< 2.:
        Bnwdsp_son[8]+=1
    elif  nvors_son[i]>= 2. and nvors_son[i]< 2.5:
        Bnwdsp_son[9]+=1
    elif  nvors_son[i]>= 2.5 and nvors_son[i]< 3.:
        Bnwdsp_son[10]+=1
    elif  nvors_son[i]>= 3. and nvors_son[i]< 3.5:
        Bnwdsp_son[11]+=1
    elif  nvors_son[i]>= 3.5:
        Bnwdsp_son[12]+=1

print('Bnwdsp=',Bnwdsp_son[:])

for i, txt in enumerate(num_djf):
    if  nvors_djf[i]< -2.:
        Bnwdsp_djf[0]+=1
        #ax.annotate(txt, (npr8[i], nwdsp8[i]),fontsize=8, ha='center', va='center')
    elif  nvors_djf[i]>= -2. and nvors_djf[i]< -1.5:
        Bnwdsp_djf[1]+=1
    elif  nvors_djf[i]>= -1.5 and nvors_djf[i]< -1.:
        Bnwdsp_djf[2]+=1
    elif  nvors_djf[i]>= -1. and nvors_djf[i]< -0.5:
        Bnwdsp_djf[3]+=1
    elif  nvors_djf[i]>= -0.5 and nvors_djf[i]< 0.:
        Bnwdsp_djf[4]+=1
    elif  nvors_djf[i]>= 0. and nvors_djf[i]< 0.5:
        Bnwdsp_djf[5]+=1
    elif  nvors_djf[i]>= 0.5 and nvors_djf[i]< 1.:
        Bnwdsp_djf[6]+=1
    elif  nvors_djf[i]>= 1. and nvors_djf[i]< 1.5:
        Bnwdsp_djf[7]+=1
    elif  nvors_djf[i]>= 1.5 and nvors_djf[i]< 2.:
        Bnwdsp_djf[8]+=1
    elif  nvors_djf[i]>= 2. and nvors_djf[i]< 2.5:
        Bnwdsp_djf[9]+=1
    elif  nvors_djf[i]>= 2.5 and nvors_djf[i]< 3.:
        Bnwdsp_djf[10]+=1
    elif  nvors_djf[i]>= 3. and nvors_djf[i]< 3.5:
        Bnwdsp_djf[11]+=1
    elif  nvors_djf[i]>= 3.5:
        Bnwdsp_djf[12]+=1

print('Bnwdsp=',Bnwdsp_djf[:])

for i, txt in enumerate(num_mam):
    if  nvors_mam[i]< -2.:
        Bnwdsp_mam[0]+=1
        #ax.annotate(txt, (npr8[i], nwdsp8[i]),fontsize=8, ha='center', va='center')
    elif  nvors_mam[i]>= -2. and nvors_mam[i]< -1.5:
        Bnwdsp_mam[1]+=1
    elif  nvors_mam[i]>= -1.5 and nvors_mam[i]< -1.:
        Bnwdsp_mam[2]+=1
    elif  nvors_mam[i]>= -1. and nvors_mam[i]< -0.5:
        Bnwdsp_mam[3]+=1
    elif  nvors_mam[i]>= -0.5 and nvors_mam[i]< 0.:
        Bnwdsp_mam[4]+=1
    elif  nvors_mam[i]>= 0. and nvors_mam[i]< 0.5:
        Bnwdsp_mam[5]+=1
    elif  nvors_mam[i]>= 0.5 and nvors_mam[i]< 1.:
        Bnwdsp_mam[6]+=1
    elif  nvors_mam[i]>= 1. and nvors_mam[i]< 1.5:
        Bnwdsp_mam[7]+=1
    elif  nvors_mam[i]>= 1.5 and nvors_mam[i]< 2.:
        Bnwdsp_mam[8]+=1
    elif  nvors_mam[i]>= 2. and nvors_mam[i]< 2.5:
        Bnwdsp_mam[9]+=1
    elif  nvors_mam[i]>= 2.5 and nvors_mam[i]< 3.:
        Bnwdsp_mam[10]+=1
    elif  nvors_mam[i]>= 3. and nvors_mam[i]< 3.5:
        Bnwdsp_mam[11]+=1
    elif  nvors_mam[i]>= 3.5:
        Bnwdsp_mam[12]+=1

print('Bnwdsp=',Bnwdsp_mam[:])

clevs=[0,5,10,20,40,60,80,100,120,140]
clevs_n=np.arange(0,3,0.2)

#fig = plt.figure(figsize=(10,4.5))
fig = plt.figure(figsize=(9.2,3.8))
#plt.title('Summation of CAPE and SCAPE')
gs = gridspec.GridSpec(1,1)
#gs = gridspec.GridSpec(1,1)

ax=plt.subplot(gs[0])

xc=np.arange(-2., 4.5, 0.5)
print (xc.shape)
width=0.18

cs2 = plt.bar(xc[:]+0.1,Bnwdsp_jja[:]*100./1410.,width,color='crimson',alpha=0.8)
cs2 = plt.bar(xc[:]+0.2,Bnwdsp_son[:]*100./1410.,width,color='orange',alpha=0.8)
cs2 = plt.bar(xc[:]+0.3,Bnwdsp_djf[:]*100./1410.,width,color='royalblue',alpha=0.8)
cs2 = plt.bar(xc[:]+0.4,Bnwdsp_mam[:]*100./1410.,width,color='green',alpha=0.7)
#plt.axvline(1, color='gray', linestyle=':')
plt.xlim(-2.1,4.6)
plt.ylim(0,6.9)
ax.set_xticks([-2,-1.5,-1,-0.5,0,0.5,1,1.5,2,2.5,3,3.5,4])
plt.xticks(fontsize=fs)
plt.yticks(fontsize=fs)
ax.set_ylabel('Frequency (%)',fontsize=fs)
#ax.text(0.98,0.75,'Frequency distribution (FD; %)',fontsize=fs, transform=ax.transAxes, ha='right')
ax.set_xlabel('Standardized subdomain-life-time averaged 850-hPa VORStav',fontsize=fs)
plt.grid(True,axis='x',linestyle=':')
ax.text(0.92,0.52,'Mean: '+'{:,.2f}'.format(meanvors*1.e5)+'x$10^{-5}\ \mathrm{s}^{-1}$',color='k',transform=ax.transAxes,ha='right',fontsize=fs)
ax.text(0.92,0.44,'SD: '+'{:,.2f}'.format(sigmvors*1.e5)+'x$10^{-5}\ \mathrm{s}^{-1}$',color='k',transform=ax.transAxes,ha='right',fontsize=fs)
#props=dict(boxstyle='round',facecolor='lightgray', alpha=0.2)
#ax.text(0.98,0.91,''+str(Q1_jja)+' cases ('+'{:,.2f}'.format(Q1_jja/15.23)+'%)',color='crimson',transform=ax.transAxes,ha='right',fontsize=fs)
#ax.text(0.02,0.91,''+str(Q2_jja)+' cases ('+'{:,.2f}'.format(Q2_jja/15.23)+'%)',color='crimson',transform=ax.transAxes,ha='left',fontsize=fs)
#ax.text(0.98,0.85,''+str(Q1_son)+' cases ('+'{:,.2f}'.format(Q1_son/15.23)+'%)',color='orange',transform=ax.transAxes,ha='right',fontsize=fs)
#ax.text(0.02,0.85,''+str(Q2_son)+' cases ('+'{:,.2f}'.format(Q2_son/15.23)+'%)',color='orange',transform=ax.transAxes,ha='left',fontsize=fs)
#ax.text(0.98,0.79,''+str(Q1_djf)+' cases ('+'{:,.2f}'.format(Q1_djf/15.23)+'%)',color='royalblue',transform=ax.transAxes,ha='right',fontsize=fs)
#ax.text(0.02,0.79,''+str(Q2_djf)+' cases ('+'{:,.2f}'.format(Q2_djf/15.23)+'%)',color='royalblue',transform=ax.transAxes,ha='left',fontsize=fs)
#ax.text(0.98,0.73,''+str(Q1_mam)+' cases ('+'{:,.2f}'.format(Q1_mam/15.23)+'%)',color='green',transform=ax.transAxes,ha='right',fontsize=fs)
#ax.text(0.02,0.73,''+str(Q2_mam)+' cases ('+'{:,.2f}'.format(Q2_mam/15.23)+'%)',color='green',transform=ax.transAxes,ha='left',fontsize=fs)
#ax.text(0.72,0.91,'JJA',color='crimson',transform=ax.transAxes,ha='left',fontsize=fs)
#ax.text(0.72,0.85,'SON',color='orange',transform=ax.transAxes,ha='left',fontsize=fs)
#ax.text(0.72,0.79,'DJF',color='royalblue',transform=ax.transAxes,ha='left',fontsize=fs)
#ax.text(0.72,0.73,'MAM',color='green',transform=ax.transAxes,ha='left',fontsize=fs)
plt.subplots_adjust(wspace=0.2, hspace=0.2)
#plt.savefig('SUBDOMAIN_850hPa_VORStavlifetimeavg_4seasonsi_rad'+RAD+'max', bbox_inches='tight', dpi=200)
plt.show()
data.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-22d74f64b27d> in <module>
#      22 RAD='200km'
#      23
# ---> 24 data = open('/home/chen/data/storm_analysis/2000-2020_cir_disttr/All_storms_kept_for_2p5Dcir_disttr_allwinds_'+RAD+'.txt','r')
#      25
#      26 num_jja=[]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/chen/data/storm_analysis/2000-2020_cir_disttr/All_storms_kept_for_2p5Dcir_disttr_allwinds_200km.txt'

# %%
df
# Out:
#          Unnamed: 0  storm  lifetime    datetime  latitude  longitude  \
# 0                 0      1         1  1979010101     41.25     275.75
# 1                 1      1         2  1979010102     41.75     276.50
# 2                 2      1         3  1979010103     42.50     277.25
# 3                 3      1         4  1979010104     43.25     278.25
# 4                 4      1         5  1979010105     43.75     279.00
# ...             ...    ...       ...         ...       ...        ...
# 1833492     1833492  24604        29  2020123119     32.00     315.00
# 1833493     1833493  24604        30  2020123120     31.75     315.00
# 1833494     1833494  24604        31  2020123121     31.75     315.00
# 1833495     1833495  24604        32  2020123122     31.75     315.00
# 1833496     1833496  24604        33  2020123123     31.50     315.00
#
#          VORS_av08 season     HU
# 0         0.000016    DJF   True
# 1         0.000017    DJF   True
# ...

# %%
df24
# Out:
#          Unnamed: 0  storm  lifetime    datetime  latitude  longitude  \
# 0                 0      1         1  1979010101     41.25     275.75
# 1                 1      1         2  1979010102     41.75     276.50
# 2                 2      1         3  1979010103     42.50     277.25
# 3                 3      1         4  1979010104     43.25     278.25
# 4                 4      1         5  1979010105     43.75     279.00
# ...             ...    ...       ...         ...       ...        ...
# 1833492     1833492  24604        29  2020123119     32.00     315.00
# 1833493     1833493  24604        30  2020123120     31.75     315.00
# 1833494     1833494  24604        31  2020123121     31.75     315.00
# 1833495     1833495  24604        32  2020123122     31.75     315.00
# 1833496     1833496  24604        33  2020123123     31.50     315.00
#
#          VORS_av08 season     HU  VORS_av08_std
# 0         0.000016    DJF   True       0.000012
# ...
