# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df24 = pd.read_csv('/pampa/cloutier/etc24_consec.csv')

# %%
son = df24.loc[(df24.season == 'SON') & (df24.HU == True)]
djf = df24.loc[(df24.season == 'DJF') & (df24.HU == True)]
mam = df24.loc[(df24.season == 'MAM') & (df24.HU == True)]
jja = df24.loc[(df24.season == 'JJA') & (df24.HU == True)]

# %%
son_vors = son.groupby('storm')['VORS_av08'].mean()
djf_vors = djf.groupby('storm')['VORS_av08'].mean()
mam_vors = mam.groupby('storm')['VORS_av08'].mean()
jja_vors = jja.groupby('storm')['VORS_av08'].mean()

# %%
son_std_vors = (son_vors - son_vors.mean()) / son_vors.std()
djf_std_vors = (djf_vors - djf_vors.mean()) / djf_vors.std()
mam_std_vors = (mam_vors - mam_vors.mean()) / mam_vors.std()
jja_std_vors = (jja_vors - jja_vors.mean()) / jja_vors.std()

# %%
bins = np.arange(-2, 5, 0.5)

# %%
son_frequency, _ = np.histogram(son_std_vors, bins=bins)
djf_frequency, _ = np.histogram(djf_std_vors, bins=bins)
mam_frequency, _ = np.histogram(mam_std_vors, bins=bins)
jja_frequency, _ = np.histogram(jja_std_vors, bins=bins)

# %%
son_tot_etc = len(son_std_vors)
djf_tot_etc = len(djf_std_vors)
mam_tot_etc = len(mam_std_vors)
jja_tot_etc = len(jja_std_vors)

son_pct = (son_frequency / son_tot_etc) * 100
djf_pct = (djf_frequency / djf_tot_etc) * 100
mam_pct = (mam_frequency / mam_tot_etc) * 100
jja_pct = (jja_frequency / jja_tot_etc) * 100

# %%
plt.rcParams['legend.handlelength'] = 1.5
plt.rcParams['legend.handleheight'] = 1
plt.rcParams['legend.numpoints'] = 1.5

plt.figure(figsize=(13,3))
plt.bar(bins[:-1]+0.1, jja_pct, width=0.15, alpha=0.7,label='JJA', color='red')
plt.bar(bins[:-1]+0.2, son_pct, width=0.15, alpha=0.8, label='SON',color='orange')
plt.bar(bins[:-1]+0.3, djf_pct, width=0.15, alpha=0.8, label='DJF', color='royalblue')
plt.bar(bins[:-1]+0.4, mam_pct, width=0.15, alpha=0.8, label='MAM', color='g')

plt.xticks(bins[:-1])

colors = ['red', 'orange', 'royalblue', 'g']
legend = plt.legend(frameon=False, ncol=4, fontsize=16, columnspacing=0.5)
for i, color in zip(range(0,4), colors):
    legend.get_texts()[i].set_position((-9, 0.5))
    first_text = legend.get_texts()[i]  # Get the first legend text
    first_text.set_fontweight('bold')  # Set font weight to bold
    first_text.set_color(color)
    first_text.set_alpha(0.8)

plt.xlabel('Standardized NNA-lifetime and 800 km averaged VORS', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Frequency (%)', fontsize=14)
plt.grid(which='major', axis='x', linestyle='dotted')
plt.show()

# %%
print('mean               : ' , "{:.2e}".format(vors.mean()))
print('standard deviation : ', "{:.2e}".format(vors.std()))
# Out:
# mean               :  2.07e-05
# standard deviation :  9.34e-06

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file
data = df24

# Filter data for ERA5 grid points within CRCM6 domain
filtered_data = data[data['HU'] == True]

# Define the seasons
seasons = ['DJF', 'MAM', 'JJA', 'SON']

# Create a list to store the frequency distributions for each season
season_distributions = []

# Iterate over each season
for season in seasons:
    # Filter data for the current season
    season_data = filtered_data[filtered_data['season'] == season]
    
    # Calculate spatiotemporal average of VORS for each storm in the season
    average_vorticity = season_data.groupby('storm')['VORS_av08'].mean()
    
    # Calculate standardized NNA-lifetime and 800 km averaged VORS
    standardized_vors = (average_vorticity - average_vorticity.mean()) / average_vorticity.std()
    
    # Create frequency distribution for the season
    bins = np.arange(-3, 4, 0.5)  # Define the bin edges
    frequency, _ = np.histogram(standardized_vors, bins=bins)
    total_storms = len(standardized_vors)
    percentage = (frequency / total_storms) * 100
    
    # Store the frequency distribution for the season
    season_distributions.append(percentage)

# Plot the frequency distributions of each season as adjacent bars
bar_width = 0.5 / len(seasons)  # Adjust the bar width based on the number of seasons
spacing = 0.1
n_bars = len(bins) - 1
total_width = bar_width * n_bars + spacing * (n_bars - 1)
x = np.arange(n_bars) * (bar_width + spacing) - total_width / 2

# Plotting each season's bars
for i, distribution in enumerate(season_distributions):
    x_offset = i * bar_width
    plt.bar(x + x_offset, distribution, width=bar_width, label=seasons[i])

plt.xlabel('Standardized NNA-lifetime and 800 km averaged VORS')
plt.ylabel('Frequency (%)')
plt.title('Frequency Distribution of Standardized VORS by Season')
plt.xticks(x, bins[:-1])  # Set x-axis tick labels
plt.legend()
plt.grid(True)
plt.show()

# Save the figure
#plt.savefig('frequency_distribution_by_season.png')
