# %%
import pandas as pd
import xarray as xr
import numpy as np

# matplotlib import
from matplotlib import pyplot as plt
import matplotlib.colors as colors
from matplotlib.colors import ListedColormap
from matplotlib import gridspec,rc

# %%
# import filtered ETCs
fetc = pd.read_csv("/pampa/cloutier/storm_tracks/filtered/etc24_consec_season.csv")

# %%
# get the average over the duration when the center was within the CRCM6 region
fetc_true = fetc.loc[fetc.HU == True].copy()
fetc_avg = fetc_true.groupby(['storm', 'season']).agg({'85WS_av08': 'mean', '10WS_av08': 'mean'}).reset_index()

mean_10 = fetc_avg['10WS_av08'].mean()
mean_85 = fetc_avg['85WS_av08'].mean()
std_10 = fetc_avg['10WS_av08'].std()
std_85 = fetc_avg['85WS_av08'].std()

# normalize the values of fetc_avg
fetc_avg['n_85WS_av08'] = (fetc_avg['85WS_av08'] - mean_85) / std_85
fetc_avg['n_10WS_av08'] = (fetc_avg['10WS_av08'] - mean_10) / std_10

# %%
# separate by season
n85wdsp_jja = fetc_avg.loc[fetc_avg.season == 'JJA']['n_85WS_av08']
n85wdsp_son = fetc_avg.loc[fetc_avg.season == 'SON']['n_85WS_av08']
n85wdsp_djf = fetc_avg.loc[fetc_avg.season == 'DJF']['n_85WS_av08']
n85wdsp_mam = fetc_avg.loc[fetc_avg.season == 'MAM']['n_85WS_av08']

n10wdsp_jja = fetc_avg.loc[fetc_avg.season == 'JJA']['n_10WS_av08']
n10wdsp_son = fetc_avg.loc[fetc_avg.season == 'SON']['n_10WS_av08']
n10wdsp_djf = fetc_avg.loc[fetc_avg.season == 'DJF']['n_10WS_av08']
n10wdsp_mam = fetc_avg.loc[fetc_avg.season == 'MAM']['n_10WS_av08']

# %%
# first quadrant count
jja_1 = len(fetc_avg.loc[(fetc_avg.season == 'JJA') & (fetc_avg.n_85WS_av08 > 1) & (fetc_avg.n_10WS_av08 > 1)])
son_1 = len(fetc_avg.loc[(fetc_avg.season == 'SON') & (fetc_avg.n_85WS_av08 > 1) & (fetc_avg.n_10WS_av08 > 1)])
djf_1 = len(fetc_avg.loc[(fetc_avg.season == 'DJF') & (fetc_avg.n_85WS_av08 > 1) & (fetc_avg.n_10WS_av08 > 1)])
mam_1 = len(fetc_avg.loc[(fetc_avg.season == 'MAM') & (fetc_avg.n_85WS_av08 > 1) & (fetc_avg.n_10WS_av08 > 1)])
#print('JJA, SON, DJF & MAM count for 1rst quadrant : ', jja_1, son_1, djf_1, mam_1)

# second quadrant count
jja_2 = len(fetc_avg.loc[(fetc_avg.season == 'JJA') & (fetc_avg.n_85WS_av08 < 1) & (fetc_avg.n_10WS_av08 > 1)])
son_2 = len(fetc_avg.loc[(fetc_avg.season == 'SON') & (fetc_avg.n_85WS_av08 < 1) & (fetc_avg.n_10WS_av08 > 1)])
djf_2 = len(fetc_avg.loc[(fetc_avg.season == 'DJF') & (fetc_avg.n_85WS_av08 < 1) & (fetc_avg.n_10WS_av08 > 1)])
mam_2 = len(fetc_avg.loc[(fetc_avg.season == 'MAM') & (fetc_avg.n_85WS_av08 < 1) & (fetc_avg.n_10WS_av08 > 1)])
#print('JJA, SON, DJF & MAM count for 2nd quadrant : ', jja_2, son_2, djf_2, mam_2)

# third quadrant count
jja_3 = len(fetc_avg.loc[(fetc_avg.season == 'JJA') & (fetc_avg.n_85WS_av08 < 1) & (fetc_avg.n_10WS_av08 < 1)])
son_3 = len(fetc_avg.loc[(fetc_avg.season == 'SON') & (fetc_avg.n_85WS_av08 < 1) & (fetc_avg.n_10WS_av08 < 1)])
djf_3 = len(fetc_avg.loc[(fetc_avg.season == 'DJF') & (fetc_avg.n_85WS_av08 < 1) & (fetc_avg.n_10WS_av08 < 1)])
mam_3 = len(fetc_avg.loc[(fetc_avg.season == 'MAM') & (fetc_avg.n_85WS_av08 < 1) & (fetc_avg.n_10WS_av08 < 1)])
#print('JJA, SON, DJF & MAM count for 3rd quadrant : ', jja_3, son_3, djf_3, mam_3)

# fourth quadrant count
jja_4 = len(fetc_avg.loc[(fetc_avg.season == 'JJA') & (fetc_avg.n_85WS_av08 > 1) & (fetc_avg.n_10WS_av08 < 1)])
son_4 = len(fetc_avg.loc[(fetc_avg.season == 'SON') & (fetc_avg.n_85WS_av08 > 1) & (fetc_avg.n_10WS_av08 < 1)])
djf_4 = len(fetc_avg.loc[(fetc_avg.season == 'DJF') & (fetc_avg.n_85WS_av08 > 1) & (fetc_avg.n_10WS_av08 < 1)])
mam_4 = len(fetc_avg.loc[(fetc_avg.season == 'MAM') & (fetc_avg.n_85WS_av08 > 1) & (fetc_avg.n_10WS_av08 < 1)])
#print('JJA, SON, DJF & MAM count for 4th quadrant : ', jja_4, son_4, djf_4, mam_4)

# %%
# percentages are calculated with respect to each seasonal sum

# first quadrant percentage
jja_pct_1 = 100 * jja_1 / (jja_1 + jja_2 + jja_3 + jja_4)
son_pct_1 = 100 * son_1 / (son_1 + son_2 + son_3 + son_4)
djf_pct_1 = 100 * djf_1 / (djf_1 + djf_2 + djf_3 + djf_4)
mam_pct_1 = 100 * mam_1 / (mam_1 + mam_2 + mam_3 + mam_4)

# second quadrant percentage
jja_pct_2 = 100 * jja_2 / (jja_1 + jja_2 + jja_3 + jja_4)
son_pct_2 = 100 * son_2 / (son_1 + son_2 + son_3 + son_4)
djf_pct_2 = 100 * djf_2 / (djf_1 + djf_2 + djf_3 + djf_4)
mam_pct_2 = 100 * mam_2 / (mam_1 + mam_2 + mam_3 + mam_4)


# third quadrant percentage
jja_pct_3 = 100 * jja_3 / (jja_1 + jja_2 + jja_3 + jja_4)
son_pct_3 = 100 * son_3 / (son_1 + son_2 + son_3 + son_4)
djf_pct_3 = 100 * djf_3 / (djf_1 + djf_2 + djf_3 + djf_4)
mam_pct_3 = 100 * mam_3 / (mam_1 + mam_2 + mam_3 + mam_4)

# fourth quadrant percentage
jja_pct_4 = 100 * jja_4 / (jja_1 + jja_2 + jja_3 + jja_4)
son_pct_4 = 100 * son_4 / (son_1 + son_2 + son_3 + son_4)
djf_pct_4 = 100 * djf_4 / (djf_1 + djf_2 + djf_3 + djf_4)
mam_pct_4 = 100 * mam_4 / (mam_1 + mam_2 + mam_3 + mam_4)

# %%
# averaged value of wind speed ratio
avg_10WS_jja = fetc_avg.loc[fetc_avg.season == 'JJA']['10WS_av08'].mean()
avg_10WS_son = fetc_avg.loc[fetc_avg.season == 'SON']['10WS_av08'].mean()
avg_10WS_djf = fetc_avg.loc[fetc_avg.season == 'DJF']['10WS_av08'].mean()
avg_10WS_mam = fetc_avg.loc[fetc_avg.season == 'MAM']['10WS_av08'].mean()

avg_85WS_jja = fetc_avg.loc[fetc_avg.season == 'JJA']['85WS_av08'].mean()
avg_85WS_son = fetc_avg.loc[fetc_avg.season == 'SON']['85WS_av08'].mean()
avg_85WS_djf = fetc_avg.loc[fetc_avg.season == 'DJF']['85WS_av08'].mean()
avg_85WS_mam = fetc_avg.loc[fetc_avg.season == 'MAM']['85WS_av08'].mean()

ratio_1085_jja = avg_10WS_jja / avg_85WS_jja
ratio_1085_son = avg_10WS_son / avg_85WS_son
ratio_1085_djf = avg_10WS_djf / avg_85WS_djf
ratio_1085_mam = avg_10WS_mam / avg_85WS_mam

# %%
fs1 = 12
fs2 = 12
fs00 = 9
fs0 = 10

# std 10 VS 850
fig = plt.figure(figsize=(10,7))
gs = gridspec.GridSpec(2,3,width_ratios=[0.26,1.0,0.06], height_ratios=[0.3,1.], hspace=0.3, wspace=0.4)
ax=plt.subplot(gs[4])

cf = plt.scatter(n85wdsp_jja, n10wdsp_jja, s=6, color='crimson', alpha=0.5, edgecolor='crimson')
cf = plt.scatter(n85wdsp_mam, n10wdsp_mam, s=6, color='green', alpha=0.5, edgecolor='green')
cf = plt.scatter(n85wdsp_djf, n10wdsp_djf, s=6, color='royalblue', alpha=0.5, edgecolor='royalblue')
cf = plt.scatter(n85wdsp_son, n10wdsp_son, s=6, color='orange', alpha=0.5, edgecolor='orange')

plt.xlim(-3.2,5.5)
plt.ylim(-3.2,5.8)

plt.axhline(y=1, color='dimgray', linestyle=':')
plt.axvline(x=1, color='dimgray', linestyle=':')

ax.set_ylabel('Standardized 10WS',fontsize=fs1)
ax.set_xlabel('Standardized 850WS',fontsize=fs1)

plt.xticks(fontsize=fs1)
plt.yticks(fontsize=fs1)

props=dict(boxstyle='round',facecolor='white', alpha=0.2)

ax.text(2.2,4.93,'11111 11   testT  1          1\n ',
        color='white',
        ha='left',fontsize=fs00,
        bbox=props)

ax.text(-2.95,4.93,'11111 11    testT  1         1\n ',
        color='white',
        ha='left',fontsize=fs00,
        bbox=props)

ax.text(-2.95,-2.82,'11111 11   testT 1           1',
                color='white',
        ha='left',fontsize=fs00,
        bbox=props)

ax.text(2.21,-2.82,'11111 11   testT  1          1',
        color='white',
        ha='left',fontsize=fs00,
        bbox=props)

ax.text(2.55,5.2,''+str(jja_1)+'',color='crimson',ha='right',fontsize=fs1,weight='bold')
ax.text(2.5,4.9,'('+'{:,.0f}'.format(jja_pct_1)+'%)',color='crimson',ha='center',fontsize=fs0)
ax.text(3.5,5.2,''+str(son_1)+'',color='orange',ha='right',fontsize=fs1,weight='bold')
ax.text(3.3,4.9,'('+'{:,.0f}'.format(son_pct_1)+'%)',color='orange',ha='center',fontsize=fs0)
ax.text(4.42,5.2,''+str(djf_1)+'',color='royalblue',ha='right',fontsize=fs1,weight='bold')
ax.text(4.14,4.9,'('+'{:,.0f}'.format(mam_pct_1)+'%)',color='royalblue',ha='center',fontsize=fs0)
ax.text(5.1,5.2,''+str(mam_1)+'',color='green',ha='right',fontsize=fs1,weight='bold')
ax.text(4.9,4.9,'('+'{:,.0f}'.format(djf_pct_1)+'%)',color='green',ha='center',fontsize=fs0)

ax.text(-2.75, 5.2,''+str(jja_2)+'',color='crimson',ha='left',fontsize=fs1,weight='bold')
ax.text(-2.58,4.9,'('+'{:,.0f}'.format(jja_pct_2)+'%)',color='crimson',ha='center',fontsize=fs0)
ax.text(-2, 5.2,''+str(son_2)+'',color='orange',ha='left',fontsize=fs1,weight='bold')
ax.text(-1.8,4.9,'('+'{:,.0f}'.format(son_pct_2)+'%)',color='orange',ha='center',fontsize=fs0)
ax.text(-1.15, 5.2,''+str(djf_2)+'',color='royalblue',ha='left',fontsize=fs1,weight='bold')
ax.text(-0.95,4.9,'('+'{:,.0f}'.format(djf_pct_2)+'%)',color='royalblue',ha='center',fontsize=fs0)
ax.text(-0.45, 5.2,''+str(mam_2)+'',color='green',ha='left',fontsize=fs1,weight='bold')
ax.text(-0.25,4.9,'('+'{:,.0f}'.format(mam_pct_2)+'%)',color='green',ha='center',fontsize=fs0)

ax.text(-2.87,-2.87,''+str(jja_3)+'',color='crimson',ha='left',fontsize=fs1,weight='bold')
ax.text(-2.10,-2.87,''+str(son_3)+'',color='orange',ha='left',fontsize=fs1,weight='bold')
ax.text(-1.35,-2.87,''+str(djf_3)+'',color='royalblue',ha='left',fontsize=fs1,weight='bold')
ax.text(-0.56,-2.87,''+str(mam_3)+'',color='green',ha='left',fontsize=fs1,weight='bold')
#
ax.text(2.7,-2.87,''+str(jja_4)+'',color='crimson',ha='right',fontsize=fs1,weight='bold')
ax.text(3.55,-2.87,''+str(son_4)+'',color='orange',ha='right',fontsize=fs1,weight='bold')
ax.text(4.34,-2.87,''+str(djf_4)+'',color='royalblue',ha='right',fontsize=fs1,weight='bold')
ax.text(5.1,-2.87,''+str(mam_4)+'',color='green',ha='right',fontsize=fs1,weight='bold')

# boxplot 85WS

ax3=plt.subplot(gs[1])
colors = ['green', 'royalblue', 'orange', 'crimson']
positions = [0, 0.6, 1.2, 1.8]
n85wdsps = [n85wdsp_mam, n85wdsp_djf, n85wdsp_son, n85wdsp_jja]

for c, p, n85 in zip(colors, positions, n85wdsps) :  

    bp = plt.boxplot(n85,positions=[p],vert=False,widths=0.37,patch_artist=True,
            boxprops=dict(facecolor=c, color=c),
            capprops=dict(color=c, linewidth=1.5),
            whiskerprops=dict(color=c, linewidth=1.5),
            flierprops=dict(color=c, markeredgecolor=c, linewidth=1.5),
            whis=[0,100],
            medianprops=dict(color='white'),showfliers=False)

plt.axvline(1, color='dimgray', linestyle=':')
plt.xticks(fontsize=fs1)
plt.xlim(-3.2,5.5)
ax3.set_xlabel('Standardized 850WS',fontsize=fs1)

ax3.set_yticklabels(['MAM','DJF','SON','JJA'],ha='right',fontsize=fs1)
ax3.set_xlabel('Standardized 850WS', fontsize=fs1)

# set season label colors
for xtick, color in zip(ax3.get_yticklabels(), colors):
    xtick.set_color(color)
    
#boxplot 10WS

colors = ['crimson', 'orange', 'royalblue', 'green']
ax0=plt.subplot(gs[3])
n10wdsps = [n10wdsp_mam, n10wdsp_djf, n10wdsp_son, n10wdsp_jja]

for c, p, n10 in zip(colors, positions, n10wdsps) : 

    bp = plt.boxplot(n10,positions=[p],widths=0.37,patch_artist=True,
            boxprops=dict(facecolor=c, color=c),
            capprops=dict(color=c, linewidth=1.5),
            whiskerprops=dict(color=c, linewidth=1.5),
            flierprops=dict(color=c, markeredgecolor=c, linewidth=1.5),
            whis=[0,100],
            medianprops=dict(color='white'),showfliers=False)
    
plt.axhline(1, color='dimgray', linestyle=':')
plt.ylim(-3.2,5.5)
plt.yticks(fontsize=fs1)

ax0.set_ylabel('Standardized 10WS',fontsize=fs1)
ax0.set_xticks([0,0.6,1.2,1.8])
ax0.set_xticklabels(['JJA','SON','DJF','MAM'],rotation=45,ha='right',fontsize=fs1)
colors = ['crimson', 'orange', 'royalblue','green']
for xtick, color in zip(ax0.get_xticklabels(), colors):
    xtick.set_color(color)

# ratio 10WS / 850WS

ax4=plt.subplot(gs[5])

ax4.scatter(1.8, ratio_1085_jja, s=120, c='crimson', marker="X")
ax4.scatter(1.8, ratio_1085_son, s=120, c='orange', marker="X")
ax4.scatter(1.8, ratio_1085_djf, s=120, c='royalblue', marker="X")
ax4.scatter(1.8, ratio_1085_mam, s=120, c='green', marker="X")

plt.yticks(ticks=[0.45, 0.46, 0.47, 0.48])
plt.ylim(0.44,0.49)
plt.xlim(1.78,1.82)
plt.yticks(fontsize=fs1)

ax4.set_ylabel('10WS/850WS',fontsize=fs1)
ax4.set_xticks([])


ax0.text(-0.45,1.42,'All-season mean, $\sigma$:',color='k',transform=ax0.transAxes,ha='left',fontsize=fs1)
ax0.text(-0.45,1.23,'10WS: '+str('{:,.1f}'.format(mean_10))+', '+str('{:,.1f}'.format(std_10))+'  (m/s)',
         color='k',transform=ax0.transAxes,ha='left',fontsize=fs1)
ax0.text(-0.45,1.32,'850WS: '+str('{:,.1f}'.format(mean_85))+', '+str('{:,.1f}'.format(std_85))+'',
         color='k',transform=ax0.transAxes,ha='left',fontsize=fs1)

ax0.text(1.15, 1.5, '(a)',transform=ax0.transAxes,ha='left',fontsize=fs1,weight='semibold')
ax0.text(-0.45, 1, '(b)',transform=ax0.transAxes,ha='left',fontsize=fs1,weight='semibold')
ax0.text(1.15, 1, '(c)',transform=ax0.transAxes,ha='left',fontsize=fs1,weight='semibold')
ax0.text(5.8, 1, '(d)',transform=ax0.transAxes,ha='left',fontsize=fs1,weight='semibold')

plt.savefig('/pampa/cloutier/fig/paperChen_fig2.png', dpi=300, bbox_inches='tight')
